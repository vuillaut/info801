# %% [markdown]
# # Pandas Exercises
#
# Original author: Tamás Gál (tamas.gal@fau.de)
#
# Adapted from [https://github.com/escape2020/school2021](https://github.com/escape2020/school2021) under MIT license.

# %%
## If working on Google Colab, uncomment these lines and run the cell

from urllib import request
from pathlib import Path
Path('data').mkdir(exist_ok=True)

request.urlretrieve('https://raw.githubusercontent.com/vuillaut/info801/main/pandas/data/neutrinos.csv',
                   'data/neutrinos.csv',
                   )
request.urlretrieve('https://raw.githubusercontent.com/vuillaut/info801/main/pandas/data/reco.csv',
                   'data/reco.csv',
                   )
# Out:
# ('data/reco.csv', <http.client.HTTPMessage at 0x7fe19e1fa790>)

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
# import seaborn as sns
import matplotlib as ml
import sys
plt = ml.pyplot
ml.rcParams['figure.figsize'] = (10.0, 5.0)

print(f"Python version: {sys.version}\n"
      f"Pandas version: {pd.__version__}\n"
      f"NumPy version: {np.__version__}\n"
      f"Matplotlib version: {ml.__version__}\n"
      # f"seaborn version: {sns.__version__}",
     )
# Out:
# Python version: 3.7.13 (default, Mar 16 2022, 17:37:17)
# [GCC 7.5.0]
# Pandas version: 1.3.5
# NumPy version: 1.21.5
# Matplotlib version: 3.2.2

# %% [markdown]
# ## Exercise 1
#
# Use the `pd.read_csv()` function to create a `DataFrame` from the dataset `data/neutrinos.csv`.

# %%
# help(pd.read_csv)

# %%
df = pd.read_csv('data/neutrinos.csv', 
            engine='python',
            on_bad_lines='skip',
            delimiter=':',
            skiprows=4,
            comment='$',
            index_col=0,
            skipfooter=1,
            decimal=','
            )

# %%
df
# Out:
#         azimuth    zenith  bjorkeny     energy   pos_x    pos_y    pos_z  \
# 0      2.349537  1.116004  0.048998   3.366400  52.740   28.831  401.186
# 1      5.575786  1.742838  0.280471   3.890000  48.369   29.865  417.282
# 2      4.656125  2.686909  0.119843   3.233500  71.722  121.449  363.077
# 3      0.520486  1.939326  0.061315   4.784000 -47.592  -84.466  350.687
# 4      2.856970  1.678897  0.061465   3.983300 -25.518   24.362  391.891
# ...         ...       ...       ...        ...     ...      ...      ...
# 60973  6.167531  1.320392  0.093289   6.696500 -25.916   91.493  444.696
# 60974  4.933224  0.729290  0.335327  22.188999 -68.489  -78.661  389.067
# 60975  1.028631  1.091732  0.325266  14.085000 -66.319   56.084  378.345
# 60976  5.993753  1.713249  0.087113   6.198300 -47.727   66.036  372.069
# 60977  2.409518  0.521768  0.183048   8.183000  62.589   90.369  449.204
#
#        proba_track  proba_cscd
# 0         0.824351    0.175649
# 1         0.818363    0.181637
# 2         0.828343    0.171657
# 3         0.842315    0.157685
# 4         0.862275    0.137725
# ...            ...         ...
# 60973     0.804391    0.195609
# 60974     0.886228    0.113772
# 60975     0.824351    0.175649
# 60976     0.976048    0.023952
# 60977     0.840319    0.159681
#
# [60978 rows x 9 columns]

# %%
df.dtypes
# Out:
# azimuth        float64
# zenith         float64
# bjorkeny       float64
# energy         float64
# pos_x          float64
# pos_y          float64
# pos_z          float64
# proba_track    float64
# proba_cscd     float64
# dtype: object

# %% [markdown]
# ## Exercise 2
#
# Create a histogram of the neutrino energies.

# %%
df.describe()
# Out:
#             azimuth        zenith      bjorkeny        energy         pos_x  \
# count  60978.000000  60978.000000  60978.000000  60978.000000  60978.000000
# mean       3.144870      1.810634      0.220735     19.360953      0.522330
# std        1.810859      0.628810      0.184152     18.705919     64.066525
# min        0.000121      0.016811      0.000050      1.462800   -357.947000
# 25%        1.577309      1.392320      0.073338      7.235925    -46.578750
# 50%        3.143121      1.852537      0.168499     12.624000      0.593500
# 75%        4.707248      2.285694      0.328061     23.422750     47.406250
# max        6.283136      3.138942      0.984511     99.997002    392.805000
#
#               pos_y         pos_z   proba_track    proba_cscd
# count  60978.000000  60978.000000  60978.000000  60978.000000
# mean       0.947249    395.419914      0.916340      0.083660
# std       71.914262     49.734274      0.065976      0.065976
# min     -362.326000    108.190000      0.800399      0.000000
# 25%      -54.061500    361.685750      0.856287      0.017964
# 50%        1.817500    396.496500      0.922156      0.077844
# 75%       55.596250    432.973250      0.982036      0.143713
# max      422.195000    701.543000      1.000000      0.199601

# %%
# df['energy'].hist()
plt.hist(df['energy'], bins=)
# Out:
# (array([27107., 16684.,  6455.,  3537.,  2232.,  1596.,  1189.,   928.,
#           678.,   572.]),
#  array([ 1.46280003, 11.31622019, 21.16964035, 31.02306051, 40.87648067,
#         50.72990084, 60.583321  , 70.43674116, 80.29016132, 90.14358149,
#         99.99700165]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Exercise 3
#
# Use the `pd.read_csv()` function to create a `DataFrame` from the dataset `data/reco.csv`.

# %%
reco = pd.read_csv('data/reco.csv', index_col=0)
reco
# Out:
#          zenith   azimuth  energy_muon  energy_neutrino  bjorken_y   quality  \
# 0      1.138133  2.180345     0.291326         1.968828      0.125 -4.354237
# 1      1.501718  4.300291     2.247325         3.973614      0.125 -4.853344
# 2      2.160066  4.228711     1.748958         3.390933      0.125 -3.836176
# 3      2.016892  0.621110     6.099985         6.643886      0.625 -4.556744
# 4      1.944401  3.030613     4.212069         5.967662      0.125 -4.927643
# ...         ...       ...          ...              ...        ...       ...
# 60973  1.299424  6.236993     4.599036         6.387176      0.125 -3.945290
# 60974  0.742736  4.839671    10.505955        12.610675      0.375 -3.999766
# 60975  1.235372  0.915573     7.150356         9.964440      0.375 -4.068371
# 60976  1.776043  5.992593     8.750033        10.912368      0.375 -4.387784
# 60977  0.678877  2.151571     4.294830         5.952899      0.125 -4.493395
#
#            pos_x       pos_y      pos_z
# 0      48.916672   32.404689  -6.251441
# 1      59.164913   26.016755  12.737107
# 2      69.988323  116.081679 -35.060437
# 3     -48.878254  -86.933884 -57.699791
# 4     -32.267179   26.163239 -12.441818
# ...          ...         ...        ...
# 60973 -18.263625   91.363175  36.575867
# 60974 -68.484308  -79.099002 -16.943958
# 60975 -65.527163   58.488387 -27.839264
# 60976 -45.701547   65.905001 -33.615596
# 60977  60.221892   92.280772  37.397762
#
# [60978 rows x 9 columns]

# %% [markdown]
# ## Exercise 4
#
# Combine the `neutrinos` and `reco` `DataFrames`  into a single `DataFrame`
#
# pd.concat()

# %%
big_table = pd.concat([df, reco.add_prefix('reco_')], axis=1)
big_table
# Out:
#         azimuth    zenith  bjorkeny     energy   pos_x    pos_y    pos_z  \
# 0      2.349537  1.116004  0.048998   3.366400  52.740   28.831  401.186
# 1      5.575786  1.742838  0.280471   3.890000  48.369   29.865  417.282
# 2      4.656125  2.686909  0.119843   3.233500  71.722  121.449  363.077
# 3      0.520486  1.939326  0.061315   4.784000 -47.592  -84.466  350.687
# 4      2.856970  1.678897  0.061465   3.983300 -25.518   24.362  391.891
# ...         ...       ...       ...        ...     ...      ...      ...
# 60973  6.167531  1.320392  0.093289   6.696500 -25.916   91.493  444.696
# 60974  4.933224  0.729290  0.335327  22.188999 -68.489  -78.661  389.067
# 60975  1.028631  1.091732  0.325266  14.085000 -66.319   56.084  378.345
# 60976  5.993753  1.713249  0.087113   6.198300 -47.727   66.036  372.069
# 60977  2.409518  0.521768  0.183048   8.183000  62.589   90.369  449.204
#
#        proba_track  proba_cscd  reco_zenith  reco_azimuth  reco_energy_muon  \
# 0         0.824351    0.175649     1.138133      2.180345          0.291326
# 1         0.818363    0.181637     1.501718      4.300291          2.247325
# 2         0.828343    0.171657     2.160066      4.228711          1.748958
# 3         0.842315    0.157685     2.016892      0.621110          6.099985
# 4         0.862275    0.137725     1.944401      3.030613          4.212069
# ...            ...         ...          ...           ...               ...
# 60973     0.804391    0.195609     1.299424      6.236993          4.599036
# 60974     0.886228    0.113772     0.742736      4.839671         10.505955
# 60975     0.824351    0.175649     1.235372      0.915573          7.150356
# 60976     0.976048    0.023952     1.776043      5.992593          8.750033
# 60977     0.840319    0.159681     0.678877      2.151571          4.294830
#
#        reco_energy_neutrino  reco_bjorken_y  reco_quality  reco_pos_x  \
# 0                  1.968828           0.125     -4.354237   48.916672
# 1                  3.973614           0.125     -4.853344   59.164913
# 2                  3.390933           0.125     -3.836176   69.988323
# 3                  6.643886           0.625     -4.556744  -48.878254
# 4                  5.967662           0.125     -4.927643  -32.267179
# ...                     ...             ...           ...         ...
# 60973              6.387176           0.125     -3.945290  -18.263625
# 60974             12.610675           0.375     -3.999766  -68.484308
# 60975              9.964440           0.375     -4.068371  -65.527163
# 60976             10.912368           0.375     -4.387784  -45.701547
# 60977              5.952899           0.125     -4.493395   60.221892
#
#        reco_pos_y  reco_pos_z
# 0       32.404689   -6.251441
# 1       26.016755   12.737107
# 2      116.081679  -35.060437
# 3      -86.933884  -57.699791
# 4       26.163239  -12.441818
# ...           ...         ...
# 60973   91.363175   36.575867
# 60974  -79.099002  -16.943958
# 60975   58.488387  -27.839264
# 60976   65.905001  -33.615596
# 60977   92.280772   37.397762
#
# [60978 rows x 18 columns]

# %%
# help(pd.concat)

# %% [markdown]
# ## Exercise 5
#
# Make a scatter plot to visualise the zenith reconstruction quality.

# %%
plt.scatter(big_table['zenith'], big_table['reco_zenith'], s=1)
plt.plot([0, 3], [0, 3], color='red')

# %% [markdown]
# ## Exercise 6
#
# Create a histogram of the cascade probabilities (__`neutrinos`__ dataset: `proba_cscd` column) for the energy ranges 1-5 GeV, 5-10 GeV, 10-20 GeV and 20-100 GeV.

# %%
plt.hist(df[(df.energy > 1) & (df.energy < 5)]['proba_cscd'])
# Out:
# (array([  34.,  169.,  333.,  548.,  806., 1024., 1354., 1588., 2046.,
#         2361.]),
#  array([0.00798403, 0.02714571, 0.04630739, 0.06546906, 0.08463074,
#         0.10379242, 0.12295409, 0.14211577, 0.16127745, 0.18043912,
#         0.1996008 ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Exercise 7
#
# Create a 2D histogram showing the distribution of the `x` and `y` values of the starting positions (`pos_x` and `pos_y`) of the neutrinos. This is basically a 2D plane of the starting positions.

# %% [markdown]
# ## Exercise 8
#
# Check out `seaborn` (`import seaborn as sns`) and recreate the 2D histogram from Exercies 7.

# %% [markdown]
# ## Exercise 9
#
# Create two histograms of the `azimuth` and `zenith` distribution side by side, in one plot (two subplots).
#
# Try `pandas` built-in matplotlib wrapper and also the raw matplotlib library.

# %% [markdown]
# ## Exercise 10
#
# Split the data into two groups: `upgoing` and `downgoing`, based on the `zenith` value (`zenith == 0` is coming from above).
#
# Try out `sns.stripplot` to verify your "cut" on the data!

# %% [markdown]
# ## Exercise 11
#
# Create a combined histogram (two histograms overlayed in the same plot) for both `upgoing` and `downgoing` datasets, showing the `zenith` angle.

# %% [markdown]
# ## Exercise 12
#
# Read a KM3NeT Event File (`data/hits.h5`) and create ToT distributions of the hits for each digital optical module (dom_id) separately.

# %% [markdown]
# ## Exercise 13
#
# Create a histogram of all time differences between consecutive hits calculated on each DOM independently

# %% [markdown]
# ## Exercise 14
#
# Examine the data for time differences below 50ns

# %% [markdown]
# ## Exercise 15
#
# Examine the hits on each PMT of each DOM
